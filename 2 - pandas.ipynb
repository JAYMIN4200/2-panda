# %%
import pandas as pd

# %%
mdf=pd.read_csv("Movie-Data.csv")
mdf
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
mdf.shape
# Out:
# (1000, 12)

# %%
mdf.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %%
mdf.head(3)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# ...

# %%
mdf.info
# Out:
# <bound method DataFrame.info of      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
mdf.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
clist=mdf.columns
clist
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
mdf=pd.read_csv("Movie-Data.csv",index_col="Genre")
mdf
# Out:
#                           Rank                    Title  \
# Genre
# Action,Adventure,Sci-Fi      1  Guardians of the Galaxy
# Adventure,Mystery,Sci-Fi     2               Prometheus
# Horror,Thriller              3                    Split
# Animation,Comedy,Family      4                     Sing
# Action,Adventure,Fantasy     5            Suicide Squad
# ...                        ...                      ...
# Crime,Drama,Mystery        996     Secret in Their Eyes
# Horror                     997          Hostel: Part II
# Drama,Music,Romance        998   Step Up 2: The Streets
# Adventure,Comedy           999             Search Party
# Comedy,Family,Fantasy     1000               Nine Lives
#
#                                                                 Description  \
# Genre
# Action,Adventure,Sci-Fi   A group of intergalactic criminals are forced ...
# Adventure,Mystery,Sci-Fi  Following clues to the origin of mankind, a te...
# ...

# %%
mdf.isnull()
# Out:
#                            Rank  Title  Description  Director  Actors   Year  \
# Genre
# Action,Adventure,Sci-Fi   False  False        False     False   False  False
# Adventure,Mystery,Sci-Fi  False  False        False     False   False  False
# Horror,Thriller           False  False        False     False   False  False
# Animation,Comedy,Family   False  False        False     False   False  False
# Action,Adventure,Fantasy  False  False        False     False   False  False
# ...                         ...    ...          ...       ...     ...    ...
# Crime,Drama,Mystery       False  False        False     False   False  False
# Horror                    False  False        False     False   False  False
# Drama,Music,Romance       False  False        False     False   False  False
# Adventure,Comedy          False  False        False     False   False  False
# Comedy,Family,Fantasy     False  False        False     False   False  False
#
# ...

# %%
mdf.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
mdf.dropna(inplace=True)

# %%
mdf.shape
# Out:
# (838, 11)

# %%
r=mdf['Revenue (Millions)']

# %%
r
# Out:
# Genre
# Action,Adventure,Sci-Fi     333.13
# Adventure,Mystery,Sci-Fi    126.46
# Horror,Thriller             138.12
# Animation,Comedy,Family     270.32
# Action,Adventure,Fantasy    325.02
#                              ...
# Action,Adventure,Horror      60.13
# Comedy                       54.72
# Horror                       17.54
# Drama,Music,Romance          58.01
# Comedy,Family,Fantasy        19.64
# Name: Revenue (Millions), Length: 838, dtype: float64

# %%
type(r)
# Out:
# pandas.core.series.Series

# %%
r.mean()
# Out:
# 84.56455847255368

# %%
 r2=mdf[["Revenue (Millions)","Year"]]
r2
# Out:
#                           Revenue (Millions)  Year
# Genre
# Action,Adventure,Sci-Fi               333.13  2014
# Adventure,Mystery,Sci-Fi              126.46  2012
# Horror,Thriller                       138.12  2016
# Animation,Comedy,Family               270.32  2016
# Action,Adventure,Fantasy              325.02  2016
# ...                                      ...   ...
# Action,Adventure,Horror                60.13  2010
# Comedy                                 54.72  2012
# Horror                                 17.54  2007
# Drama,Music,Romance                    58.01  2008
# Comedy,Family,Fantasy                  19.64  2016
#
# [838 rows x 2 columns]

# %%
type(r2)
# Out:
# pandas.core.frame.DataFrame

# %%
r.fillna(r.mean,inplace=True)

# %%
rmean=r.mean()
rmean
# Out:
# 84.56455847255368

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 838 entries, Action,Adventure,Sci-Fi to Comedy,Family,Fantasy
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Description         838 non-null    object
#  3   Director            838 non-null    object
#  4   Actors              838 non-null    object
#  5   Year                838 non-null    int64
#  6   Runtime (Minutes)   838 non-null    int64
#  7   Rating              838 non-null    float64
#  8   Votes               838 non-null    int64
#  9   Revenue (Millions)  838 non-null    float64
#  10  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 110.9+ KB

# %%
r.fillna(rmean,inplace=True)
r
# Out:
# Genre
# Action,Adventure,Sci-Fi     333.13
# Adventure,Mystery,Sci-Fi    126.46
# Horror,Thriller             138.12
# Animation,Comedy,Family     270.32
# Action,Adventure,Fantasy    325.02
#                              ...
# Action,Adventure,Horror      60.13
# Comedy                       54.72
# Horror                       17.54
# Drama,Music,Romance          58.01
# Comedy,Family,Fantasy        19.64
# Name: Revenue (Millions), Length: 838, dtype: float64

# %%
r4=mdf['Metascore']
r4
# Out:
# Genre
# Action,Adventure,Sci-Fi     76.0
# Adventure,Mystery,Sci-Fi    65.0
# Horror,Thriller             62.0
# Animation,Comedy,Family     59.0
# Action,Adventure,Fantasy    40.0
#                             ...
# Action,Adventure,Horror     37.0
# Comedy                      48.0
# Horror                      46.0
# Drama,Music,Romance         50.0
# Comedy,Family,Fantasy       11.0
# Name: Metascore, Length: 838, dtype: float64

# %%
m=mdf["Metascore"]
m
# Out:
# Genre
# Action,Adventure,Sci-Fi     76.0
# Adventure,Mystery,Sci-Fi    65.0
# Horror,Thriller             62.0
# Animation,Comedy,Family     59.0
# Action,Adventure,Fantasy    40.0
#                             ...
# Action,Adventure,Horror     37.0
# Comedy                      48.0
# Horror                      46.0
# Drama,Music,Romance         50.0
# Comedy,Family,Fantasy       11.0
# Name: Metascore, Length: 838, dtype: float64

# %%
m.isnull().sum()
# Out:
# 0

# %%
m.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of Genre
# Action,Adventure,Sci-Fi     76.0
# Adventure,Mystery,Sci-Fi    65.0
# Horror,Thriller             62.0
# Animation,Comedy,Family     59.0
# Action,Adventure,Fantasy    40.0
#                             ...
# Action,Adventure,Horror     37.0
# Comedy                      48.0
# Horror                      46.0
# Drama,Music,Romance         50.0
# Comedy,Family,Fantasy       11.0
# Name: Metascore, Length: 838, dtype: float64>

# %%
m.fillna(m.mean,inplace=True)

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 838 entries, Action,Adventure,Sci-Fi to Comedy,Family,Fantasy
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Description         838 non-null    object
#  3   Director            838 non-null    object
#  4   Actors              838 non-null    object
#  5   Year                838 non-null    int64
#  6   Runtime (Minutes)   838 non-null    int64
#  7   Rating              838 non-null    float64
#  8   Votes               838 non-null    int64
#  9   Revenue (Millions)  838 non-null    float64
#  10  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 110.9+ KB

# %%
m1=mdf["Year"]
m1
# Out:
# Genre
# Action,Adventure,Sci-Fi     2014
# Adventure,Mystery,Sci-Fi    2012
# Horror,Thriller             2016
# Animation,Comedy,Family     2016
# Action,Adventure,Fantasy    2016
#                             ...
# Action,Adventure,Horror     2010
# Comedy                      2012
# Horror                      2007
# Drama,Music,Romance         2008
# Comedy,Family,Fantasy       2016
# Name: Year, Length: 838, dtype: int64

# %%
m1.isnull().sum()
# Out:
# 0

# %%
m1.fillna(2012,inplace=True)

# %%
m1
# Out:
# Genre
# Action,Adventure,Sci-Fi     2014
# Adventure,Mystery,Sci-Fi    2012
# Horror,Thriller             2016
# Animation,Comedy,Family     2016
# Action,Adventure,Fantasy    2016
#                             ...
# Action,Adventure,Horror     2010
# Comedy                      2012
# Horror                      2007
# Drama,Music,Romance         2008
# Comedy,Family,Fantasy       2016
# Name: Year, Length: 838, dtype: int64

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 838 entries, Action,Adventure,Sci-Fi to Comedy,Family,Fantasy
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Description         838 non-null    object
#  3   Director            838 non-null    object
#  4   Actors              838 non-null    object
#  5   Year                838 non-null    int64
#  6   Runtime (Minutes)   838 non-null    int64
#  7   Rating              838 non-null    float64
#  8   Votes               838 non-null    int64
#  9   Revenue (Millions)  838 non-null    float64
#  10  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 110.9+ KB
